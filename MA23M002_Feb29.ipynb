# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavtk1/ED5340-CW/blob/main/MA23M002_Feb29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5, 5, 100)
y = x**2

# %%
plt.plot(x,y, 'o--', color = 'red', lw = 2.5, ms = 7)

# %%
# figure and axes
fig, ax = plt.subplots(2, 2, figsize=(4,4))
print(type(fig))
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'numpy.ndarray'>

# %%
z = x**4

# %%
#using subplots
fig, ax = plt.subplots(2, 2, figsize=(4,4))
ax[0][0].plot(x,y)
ax[0][1].plot(x,x**3)
ax[1][0].plot(x,x+4)
ax[1][1].plot(x,z)

# %%
x = np.arange(-2,2,0.01)
y = x**2
plt.plot(x,y)

# %%
t = np.arange(-3,3,0.1)
x = t
y = t**2
z = t**3
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111, projection = '3d')
ax.plot(x,y,z)

# %%
x1 = np.arange(-2,2,0.1)
y1 = np.arange(-2,2,0.1)
X, Y = np.meshgrid(x1, y1)
Z = X**2 + Y**2
fig1 = plt.figure(figsize=(4,4))
ax1 = fig1.add_subplot(111, projection = '3d')
ax1.plot_surface(X,Y,Z)

# %%
# Contour plot
fig = plt.figure(figsize=(5,5))
ax1 = fig.add_subplot(111)
cp = plt.contourf(X,Y,Z)
plt.clabel(cp, fontsize=1)
# Out:
# <a list of 20 text.Text objects>
